# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\DELL\\Desktop\\odi.csv")

# %%
df
# Out:
#          mid        date                                              venue  \
# 0          1  2006-06-13               Civil Service Cricket Club, Stormont
# 1          1  2006-06-13               Civil Service Cricket Club, Stormont
# 2          1  2006-06-13               Civil Service Cricket Club, Stormont
# 3          1  2006-06-13               Civil Service Cricket Club, Stormont
# 4          1  2006-06-13               Civil Service Cricket Club, Stormont
# ...      ...         ...                                                ...
# 350894  1188  2017-07-10  Mahinda Rajapaksa International Cricket Stadiu...
# 350895  1188  2017-07-10  Mahinda Rajapaksa International Cricket Stadiu...
# 350896  1188  2017-07-10  Mahinda Rajapaksa International Cricket Stadiu...
# 350897  1188  2017-07-10  Mahinda Rajapaksa International Cricket Stadiu...
# 350898  1188  2017-07-10  Mahinda Rajapaksa International Cricket Stadiu...
#
# ...

# %%
#Feature and Target
X = df.iloc[:,[7,8,9,10,11,12,13]].values
Y = df.iloc[:, 14].values

# %%
#train-test splitting
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state =123)

# %%
#Feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Linear Regression
#statsmodel for constant and model OLS
import statsmodels.api as sm
#add constant
X_train_const=sm.add_constant(X_train)
model1=sm.OLS(Y_train, X_train_const).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.528
# Model:                            OLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                 3.924e+04
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):               0.00
# Time:                        23:38:07   Log-Likelihood:            -1.2718e+06
# No. Observations:              245629   AIC:                         2.544e+06
# Df Residuals:                  245621   BIC:                         2.544e+06
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        255.3133      0.087   2950.108      0.000     255.144     255.483
# ...

# %%
model1.params
# Out:
# array([ 2.55313273e+02,  8.38591754e+01, -3.01613439e+01, -5.02117271e+01,
#         2.64643045e+00, -3.23015333e+00, -1.69968580e-01, -4.47450244e-01])

# %%
#using scikit learn- linear Regression
from sklearn.linear_model import LinearRegression
from sklearn import metrics
model2=LinearRegression()
model2.fit(X_train, Y_train)
Y_pred=model2.predict(X_test)

# %%
import numpy as np
#means square error
rm=(np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))/100
accuracy=1-rm
print(accuracy)
#accuracy is around 57%
# Out:
# 0.5721205824153615

# %%
#decision tree regression
from sklearn.tree import DecisionTreeRegressor  
regressor = DecisionTreeRegressor(random_state = 123)  
model3=regressor.fit(X_train, Y_train) 
Y_pred2=model3.predict(X_test)
rm2=(np.sqrt(metrics.mean_squared_error(Y_test, Y_pred2)))/100
accuracy2=1-rm2
print(accuracy2)
#accuracy is around 64%
# Out:
# 0.6430097723593549

# %%
#random forest regression
from sklearn.ensemble import RandomForestRegressor 
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0) 
model4=regressor.fit(X_train, Y_train) 
Y_pred3=model4.predict(X_test)
rm3=(np.sqrt(metrics.mean_squared_error(Y_test, Y_pred3)))/100
accuracy3=1-rm3
print(accuracy3)
#accuracy is around 72%
#best performance by random forest
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 0.7234372237218392
